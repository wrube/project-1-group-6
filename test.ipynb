# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02"

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
from pprint import pprint 
import json
pprint(response.json())
# Out:
# {'bbox': [-179.688, -56.1218, -2.884, 167.8106, 64.8102, 582.05],
#  'features': [{'geometry': {'coordinates': [-116.7776667, 33.6633333, 11.008],
#                             'type': 'Point'},
#                'id': 'ci11408890',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408890',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408890&format=geojson',
#                               'dmin': 0.06729,
#                               'felt': None,
#                               'gap': 51,
#                               'ids': ',ci11408890,',
#                               'mag': 1.29,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 39,
#                               'place': '10km SSW of Idyllwild, CA',
#                               'rms': 0.09,
#                               'sig': 26,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388620296020,
#                               'title': 'M 1.3 - 10km SSW of Idyllwild, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1457728844428,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408890'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-151.6459, 63.102, 14.1],
#                             'type': 'Point'},
#                'id': 'ak01421ig3u',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '01421ig3u',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak01421ig3u&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992887,ak01421ig3u,',
#                               'mag': 1.1,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': 'Central Alaska',
#                               'rms': 0.57,
#                               'sig': 19,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388620046501,
#                               'title': 'M 1.1 - Central Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1689800179099,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01421ig3u'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-150.0165, 61.4581, 44.6],
#                             'type': 'Point'},
#                'id': 'ak01421i2zj',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '01421i2zj',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak01421i2zj&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10934318,ak01421i2zj,',
#                               'mag': 1.2,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '7 km SSW of Big Lake, Alaska',
#                               'rms': 0.47,
#                               'sig': 22,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388619956476,
#                               'title': 'M 1.2 - 7 km SSW of Big Lake, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,cap,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1689800177820,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01421i2zj'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-150.8276, 62.7884, 87.6],
#                             'type': 'Point'},
#                'id': 'ak01421heui',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '01421heui',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak01421heui&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992885,ak01421heui,',
#                               'mag': 1.4,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '32 km N of Petersville, Alaska',
#                               'rms': 0.35,
#                               'sig': 30,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388619763623,
#                               'title': 'M 1.4 - 32 km N of Petersville, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1692374394274,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01421heui'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-71.621, -29.888, 40],
#                             'type': 'Point'},
#                'id': 'usc000mnnn',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'c000mnnn',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usc000mnnn&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',usc000mnnn,',
#                               'mag': 4,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '28 km WNW of Coquimbo, Chile',
#                               'rms': 3.09,
#                               'sig': 246,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388619735000,
#                               'title': 'M 4.0 - 28 km WNW of Coquimbo, Chile',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usc000mnnn'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7839966, 38.8071671, 0.013],
#                             'type': 'Point'},
#                'id': 'nc72134466',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134466',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134466&format=geojson',
#                               'dmin': 0.007207,
#                               'felt': None,
#                               'gap': 90,
#                               'ids': ',nc72134466,',
#                               'mag': 0.53,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 8,
#                               'place': '5 km WSW of Cobb, California',
#                               'rms': 0.03,
#                               'sig': 4,
#                               'sources': ',nc,',
#                               'status': 'automatic',
#                               'time': 1388619644020,
#                               'title': 'M 0.5 - 5 km WSW of Cobb, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1486063047447,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134466'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.8948333, 37.6433333, -0.446],
#                             'type': 'Point'},
#                'id': 'nc72134461',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134461',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134461&format=geojson',
#                               'dmin': 0.001802,
#                               'felt': None,
#                               'gap': 133,
#                               'ids': ',nc72134461,',
#                               'mag': 0.7,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 16,
#                               'place': '6 km E of Mammoth Lakes, California',
#                               'rms': 0.08,
#                               'sig': 8,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388619483870,
#                               'title': 'M 0.7 - 6 km E of Mammoth Lakes, '
#                                        'California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1486063041500,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134461'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-116.562, 33.5175, 8.148],
#                             'type': 'Point'},
#                'id': 'ci11408882',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408882',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408882&format=geojson',
#                               'dmin': 0.04045,
#                               'felt': None,
#                               'gap': 92,
#                               'ids': ',ci11408882,',
#                               'mag': 0.47,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 17,
#                               'place': '11km ESE of Anza, CA',
#                               'rms': 0.09,
#                               'sig': 3,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388619402290,
#                               'title': 'M 0.5 - 11km ESE of Anza, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1457688589278,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408882'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4646, 38.5678, 8.7],
#                             'type': 'Point'},
#                'id': 'nn00557597',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00557597',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00557597&format=geojson',
#                               'dmin': 0.075,
#                               'felt': None,
#                               'gap': 155.68,
#                               'ids': ',nn00557597,',
#                               'mag': 0.6,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 5,
#                               'place': '14 km ENE of Hawthorne, Nevada',
#                               'rms': 0.1066,
#                               'sig': 6,
#                               'sources': ',nn,',
#                               'status': 'reviewed',
#                               'time': 1388619146923,
#                               'title': 'M 0.6 - 14 km ENE of Hawthorne, Nevada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1530313185339,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00557597'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-176.8207, -23.9576, 219.29],
#                             'type': 'Point'},
#                'id': 'usb000m2w9',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'b000m2w9',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usb000m2w9&format=geojson',
#                               'dmin': 5.358,
#                               'felt': None,
#                               'gap': 136,
#                               'ids': ',usb000m2w9,',
#                               'mag': 4.2,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': 'south of the Fiji Islands',
#                               'rms': 1.38,
#                               'sig': 271,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388619137530,
#                               'title': 'M 4.2 - south of the Fiji Islands',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usb000m2w9'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-167.3021, 53.3823, 12.7],
#                             'type': 'Point'},
#                'id': 'ak01421dpqr',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '01421dpqr',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak01421dpqr&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992884,ak01421dpqr,',
#                               'mag': 1.8,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '74 km SW of Unalaska, Alaska',
#                               'rms': 0.64,
#                               'sig': 50,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388618718598,
#                               'title': 'M 1.8 - 74 km SW of Unalaska, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1689800071653,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak01421dpqr'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [128.3539, -6.1578, 359.16],
#                             'type': 'Point'},
#                'id': 'usb000m2wa',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'b000m2wa',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usb000m2wa&format=geojson',
#                               'dmin': 3.439,
#                               'felt': None,
#                               'gap': 82,
#                               'ids': ',usb000m2wa,',
#                               'mag': 4.2,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '272 km S of Ambon, Indonesia',
#                               'rms': 1.05,
#                               'sig': 271,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388618653890,
#                               'title': 'M 4.2 - 272 km S of Ambon, Indonesia',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usb000m2wa'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-123.1971667, 48.4256667, 11.92],
#                             'type': 'Point'},
#                'id': 'uw60664506',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '60664506',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw60664506&format=geojson',
#                               'dmin': 0.08557,
#                               'felt': None,
#                               'gap': 115,
#                               'ids': ',uw60664506,',
#                               'mag': 0.64,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'uw',
#                               'nst': 10,
#                               'place': '8 km ESE of Oak Bay, Canada',
#                               'rms': 0.09,
#                               'sig': 6,
#                               'sources': ',uw,',
#                               'status': 'reviewed',
#                               'time': 1388618284550,
#                               'title': 'M 0.6 - 8 km ESE of Oak Bay, Canada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1469215317300,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw60664506'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4594, 38.5819, 10.7],
#                             'type': 'Point'},
#                'id': 'nn00557596',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00557596',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00557596&format=geojson',
#                               'dmin': 0.068,
#                               'felt': None,
#                               'gap': 193.46,
#                               'ids': ',nn00557596,',
#                               'mag': 0.3,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 4,
#                               'place': '15 km ENE of Hawthorne, Nevada',
#                               'rms': 0.1151,
#                               'sig': 1,
#                               'sources': ',nn,',
#                               'status': 'reviewed',
#                               'time': 1388618225608,
#                               'title': 'M 0.3 - 15 km ENE of Hawthorne, Nevada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1530313185251,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00557596'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-66.1455, 18.3276, 58],
#                             'type': 'Point'},
#                'id': 'pr14001004',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '14001004',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr14001004&format=geojson',
#                               'dmin': 0.28027437,
#                               'felt': None,
#                               'gap': 165.6,
#                               'ids': ',pr14001004,usc000lvhk,',
#                               'mag': 2.7,
#                               'magType': 'Md',
#                               'mmi': None,
#                               'net': 'pr',
#                               'nst': 15,
#                               'place': '4 km SW of Guaynabo, Puerto Rico',
#                               'rms': 0.23,
#                               'sig': 112,
#                               'sources': ',pr,us,',
#                               'status': 'REVIEWED',
#                               'time': 1388617808800,
#                               'title': 'M 2.7 - 4 km SW of Guaynabo, Puerto '
#                                        'Rico',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr14001004'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-115.6021667, 33.1823333, 0.383],
#                             'type': 'Point'},
#                'id': 'ci11408874',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408874',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408874&format=geojson',
#                               'dmin': 0.01072,
#                               'felt': None,
#                               'gap': 97,
#                               'ids': ',ci11408874,',
#                               'mag': 0.3,
#                               'magType': 'mh',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 10,
#                               'place': '10km SW of Niland, CA',
#                               'rms': 0.06,
#                               'sig': 1,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388617699360,
#                               'title': 'M 0.3 - 10km SW of Niland, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1457682058070,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408874'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-95.659, 17.7689, 120.1],
#                             'type': 'Point'},
#                'id': 'usc000mh9r',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'c000mh9r',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usc000mh9r&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',usc000mh9r,',
#                               'mag': 4,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '8 km N of Santa Teresa, Mexico',
#                               'rms': 1.12,
#                               'sig': 246,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388617516400,
#                               'title': 'M 4.0 - 8 km N of Santa Teresa, Mexico',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usc000mh9r'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-116.1108, 36.6771, 0],
#                             'type': 'Point'},
#                'id': 'nn00432852',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00432852',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00432852&format=geojson',
#                               'dmin': 0.021,
#                               'felt': None,
#                               'gap': 148.56,
#                               'ids': ',nn00432852,',
#                               'mag': 0.3,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 7,
#                               'place': '41 km WNW of Indian Springs, Nevada',
#                               'rms': 0.0885,
#                               'sig': 1,
#                               'sources': ',nn,',
#                               'status': 'reviewed',
#                               'time': 1388617471115,
#                               'title': 'M 0.3 - 41 km WNW of Indian Springs, '
#                                        'Nevada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,general-link,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1530313183570,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00432852'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.8601667, 37.5738333, 5.339],
#                             'type': 'Point'},
#                'id': 'nc72134456',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134456',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134456&format=geojson',
#                               'dmin': 0.02973,
#                               'felt': None,
#                               'gap': 90,
#                               'ids': ',nc72134456,',
#                               'mag': 0.35,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 19,
#                               'place': '12 km SE of Mammoth Lakes, California',
#                               'rms': 0.05,
#                               'sig': 2,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388617009820,
#                               'title': 'M 0.4 - 12 km SE of Mammoth Lakes, '
#                                        'California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1486063035481,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134456'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-115.3121667, 32.2258333, 8.027],
#                             'type': 'Point'},
#                'id': 'ci11408866',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408866',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408866&format=geojson',
#                               'dmin': 0.1932,
#                               'felt': None,
#                               'gap': 273,
#                               'ids': ',ci11408866,',
#                               'mag': 1.88,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 11,
#                               'place': '13km W of Alberto Oviedo Mota, B.C., '
#                                        'MX',
#                               'rms': 0.14,
#                               'sig': 54,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388616646650,
#                               'title': 'M 1.9 - 13km W of Alberto Oviedo Mota, '
#                                        'B.C., MX',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1457662449118,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408866'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7453333, 38.7745, -0.44],
#                             'type': 'Point'},
#                'id': 'nc72134451',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134451',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134451&format=geojson',
#                               'dmin': 0.01102,
#                               'felt': None,
#                               'gap': 68,
#                               'ids': ',nc72134451,',
#                               'mag': 1.24,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 35,
#                               'place': '1km ESE of The Geysers, CA',
#                               'rms': 0.06,
#                               'sig': 24,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388616254500,
#                               'title': 'M 1.2 - 1km ESE of The Geysers, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1559857147970,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134451'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.3738333, 37.3576667, 5.746],
#                             'type': 'Point'},
#                'id': 'nc72134446',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134446',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134446&format=geojson',
#                               'dmin': 0.07568,
#                               'felt': None,
#                               'gap': 152,
#                               'ids': ',nc72134446,nn00432850,',
#                               'mag': 0.68,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 5,
#                               'place': '1 km ESE of Bishop, California',
#                               'rms': 0.05,
#                               'sig': 7,
#                               'sources': ',nc,nn,',
#                               'status': 'reviewed',
#                               'time': 1388616011920,
#                               'title': 'M 0.7 - 1 km ESE of Bishop, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1530313184605,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134446'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7716675, 38.8033333, 1.12],
#                             'type': 'Point'},
#                'id': 'nc72134441',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134441',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134441&format=geojson',
#                               'dmin': 0.01622,
#                               'felt': None,
#                               'gap': 111,
#                               'ids': ',nc72134441,',
#                               'mag': 0.52,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 6,
#                               'place': '4 km WSW of Cobb, California',
#                               'rms': 0.02,
#                               'sig': 4,
#                               'sources': ',nc,',
#                               'status': 'automatic',
#                               'time': 1388615750350,
#                               'title': 'M 0.5 - 4 km WSW of Cobb, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1486063013394,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134441'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.8146667, 38.8096667, 2.25],
#                             'type': 'Point'},
#                'id': 'nc72134436',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134436',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134436&format=geojson',
#                               'dmin': 0.01171,
#                               'felt': None,
#                               'gap': 44,
#                               'ids': ',nc72134436,',
#                               'mag': 1.05,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 42,
#                               'place': '8 km W of Cobb, California',
#                               'rms': 0.04,
#                               'sig': 17,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388615736120,
#                               'title': 'M 1.1 - 8 km W of Cobb, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1486063005672,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134436'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [167.2381, -13.7511, 205.98],
#                             'type': 'Point'},
#                'id': 'usb000m2w8',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'b000m2w8',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usb000m2w8&format=geojson',
#                               'dmin': 8.309,
#                               'felt': None,
#                               'gap': 94,
#                               'ids': ',usb000m2w8,',
#                               'mag': 4.6,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '36 km WNW of Sola, Vanuatu',
#                               'rms': 0.97,
#                               'sig': 326,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388615631260,
#                               'title': 'M 4.6 - 36 km WNW of Sola, Vanuatu',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1394151954000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usb000m2w8'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4346, 38.5729, 5.5],
#                             'type': 'Point'},
#                'id': 'nn00557595',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '00557595',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00557595&format=geojson',
#                               'dmin': 0.088,
#                               'felt': None,
#                               'gap': 173.49,
#                               'ids': ',nn00557595,',
#                               'mag': 0.8,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'nn',
#                               'nst': 4,
#                               'place': '17 km ENE of Hawthorne, Nevada',
#                               'rms': 0.0336,
#                               'sig': 10,
#                               'sources': ',nn,',
#                               'status': 'reviewed',
#                               'time': 1388615608908,
#                               'title': 'M 0.8 - 17 km ENE of Hawthorne, Nevada',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1530313185162,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00557595'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-121.7506667, 46.8501667, 1.436],
#                             'type': 'Point'},
#                'id': 'uw60664496',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '60664496',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw60664496&format=geojson',
#                               'dmin': 0.01894,
#                               'felt': None,
#                               'gap': 71,
#                               'ids': ',uw60664496,',
#                               'mag': -0.33,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'uw',
#                               'nst': 9,
#                               'place': '23 km ENE of Ashford, Washington',
#                               'rms': 0.08,
#                               'sig': 0,
#                               'sources': ',uw,',
#                               'status': 'reviewed',
#                               'time': 1388615267370,
#                               'title': 'M -0.3 - 23 km ENE of Ashford, '
#                                        'Washington',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',origin,phase-data,',
#                               'tz': None,
#                               'updated': 1469215317030,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw60664496'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-116.7493333, 33.7068333, 17.148],
#                             'type': 'Point'},
#                'id': 'ci11408858',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '11408858',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci11408858&format=geojson',
#                               'dmin': 0.02963,
#                               'felt': None,
#                               'gap': 165,
#                               'ids': ',ci11408858,',
#                               'mag': 0.53,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 15,
#                               'place': '5km SW of Idyllwild, CA',
#                               'rms': 0.04,
#                               'sig': 4,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388615009140,
#                               'title': 'M 0.5 - 5km SW of Idyllwild, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1457735530566,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408858'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4288333, 37.6036667, 7.766],
#                             'type': 'Point'},
#                'id': 'nc72134431',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134431',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134431&format=geojson',
#                               'dmin': 0.05676,
#                               'felt': None,
#                               'gap': 73,
#                               'ids': ',nc72134431,nn00432849,ci11408850,',
#                               'mag': 2.51,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 42,
#                               'place': '21 km ENE of Swall Meadows, California',
#                               'rms': 0.06,
#                               'sig': 97,
#                               'sources': ',nc,nn,ci,',
#                               'status': 'reviewed',
#                               'time': 1388614835770,
#                               'title': 'M 2.5 - 21 km ENE of Swall Meadows, '
#                                        'California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,focal-mechanism,general-link,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1530313182678,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72134431'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7926636, 38.8081665, 2.48],
#                             'type': 'Point'},
#                'id': 'nc72134426',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72134426',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72134426&format=geojson',
# ...
#                               'mag': 0.1,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ci',
#                               'nst': 15,
#                               'place': '21km ESE of Anza, CA',
#                               'rms': 0.1,
#                               'sig': 0,
#                               'sources': ',ci,',
#                               'status': 'reviewed',
#                               'time': 1388537639130,
#                               'title': 'M 0.1 - 21km ESE of Anza, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1457762408379,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci11408434'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-144.7523, 63.236, 11.7],
#                             'type': 'Point'},
#                'id': 'ak0141ntf85',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '0141ntf85',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0141ntf85&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992831,ak0141ntf85,',
#                               'mag': 1.3,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '46 km ENE of Paxson, Alaska',
#                               'rms': 0.57,
#                               'sig': 26,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388537221015,
#                               'title': 'M 1.3 - 46 km ENE of Paxson, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1689799961311,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0141ntf85'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.5188333, 46.0926667, 13.97],
#                             'type': 'Point'},
#                'id': 'uw60664276',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '60664276',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw60664276&format=geojson',
#                               'dmin': 0.08565,
#                               'felt': None,
#                               'gap': 182,
#                               'ids': ',uw60664276,',
#                               'mag': 0.22,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'uw',
#                               'nst': 9,
#                               'place': 'Washington',
#                               'rms': 0.1,
#                               'sig': 1,
#                               'sources': ',uw,',
#                               'status': 'reviewed',
#                               'time': 1388536764680,
#                               'title': 'M 0.2 - Washington',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1469215315430,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw60664276'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7776642, 38.8320007, 0.187],
#                             'type': 'Point'},
#                'id': 'nc72133846',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72133846',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72133846&format=geojson',
#                               'dmin': 0.006306,
#                               'felt': None,
#                               'gap': 90,
#                               'ids': ',nc72133846,',
#                               'mag': 1.07,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 14,
#                               'place': '4 km WNW of Cobb, California',
#                               'rms': 0.05,
#                               'sig': 18,
#                               'sources': ',nc,',
#                               'status': 'automatic',
#                               'time': 1388536602470,
#                               'title': 'M 1.1 - 4 km WNW of Cobb, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',nearby-cities,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1486062284045,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72133846'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-155.0353333, 19.3246667, 1.294],
#                             'type': 'Point'},
#                'id': 'hv60614021',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '60614021',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv60614021&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': 207,
#                               'ids': ',hv60614021,',
#                               'mag': 2.08,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'hv',
#                               'nst': 38,
#                               'place': '18 km SE of Fern Forest, Hawaii',
#                               'rms': 0.14,
#                               'sig': 67,
#                               'sources': ',hv,',
#                               'status': 'reviewed',
#                               'time': 1388536590280,
#                               'title': 'M 2.1 - 18 km SE of Fern Forest, '
#                                        'Hawaii',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1594067950160,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv60614021'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-153.0185, 60.0872, 105.8],
#                             'type': 'Point'},
#                'id': 'ak0141nol21',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '0141nol21',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0141nol21&format=geojson',
#                               'dmin': None,
#                               'felt': None,
#                               'gap': None,
#                               'ids': ',ak10992830,ak0141nol21,',
#                               'mag': 2,
#                               'magType': 'ml',
#                               'mmi': None,
#                               'net': 'ak',
#                               'nst': None,
#                               'place': '69 km ENE of Pedro Bay, Alaska',
#                               'rms': 0.77,
#                               'sig': 62,
#                               'sources': ',ak,ak,',
#                               'status': 'reviewed',
#                               'time': 1388535883771,
#                               'title': 'M 2.0 - 69 km ENE of Pedro Bay, Alaska',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',associate,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1689799960034,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0141nol21'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.8435, 38.8216667, 2.14],
#                             'type': 'Point'},
#                'id': 'nc72133841',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '72133841',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc72133841&format=geojson',
#                               'dmin': 0.007207,
#                               'felt': None,
#                               'gap': 65,
#                               'ids': ',nc72133841,',
#                               'mag': 0.57,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'nc',
#                               'nst': 30,
#                               'place': '10 km W of Cobb, California',
#                               'rms': 0.04,
#                               'sig': 5,
#                               'sources': ',nc,',
#                               'status': 'reviewed',
#                               'time': 1388535010970,
#                               'title': 'M 0.6 - 10 km W of Cobb, California',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',nearby-cities,origin,phase-data,scitech-link,',
#                               'tz': None,
#                               'updated': 1486062277926,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc72133841'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.7498333, 44.408, -0.348],
#                             'type': 'Point'},
#                'id': 'uw60664271',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': '60664271',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw60664271&format=geojson',
#                               'dmin': 0.1157,
#                               'felt': None,
#                               'gap': 179,
#                               'ids': ',uw60664271,',
#                               'mag': 2.2,
#                               'magType': 'md',
#                               'mmi': None,
#                               'net': 'uw',
#                               'nst': 4,
#                               'place': '1 km NW of Sweet Home, Oregon',
#                               'rms': 0.07,
#                               'sig': 74,
#                               'sources': ',uw,',
#                               'status': 'reviewed',
#                               'time': 1388534755060,
#                               'title': 'M 2.2 Explosion - 1 km NW of Sweet '
#                                        'Home, Oregon',
#                               'tsunami': 0,
#                               'type': 'explosion',
#                               'types': ',cap,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1469215315190,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw60664271'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-175.5282, -18.4965, 217.9],
#                             'type': 'Point'},
#                'id': 'usc000lv5j',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'c000lv5j',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usc000lv5j&format=geojson',
#                               'dmin': 5.337,
#                               'felt': None,
#                               'gap': 41,
#                               'ids': ',usc000lv5j,',
#                               'mag': 4.5,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '163 km W of Neiafu, Tonga',
#                               'rms': 0.6,
#                               'sig': 312,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388534728830,
#                               'title': 'M 4.5 - 163 km W of Neiafu, Tonga',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1394151953000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usc000lv5j'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [120.2389, 19.0868, 10.07],
#                             'type': 'Point'},
#                'id': 'usc000lv5e',
#                'properties': {'alert': None,
#                               'cdi': None,
#                               'code': 'c000lv5e',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usc000lv5e&format=geojson',
#                               'dmin': 3.794,
#                               'felt': None,
#                               'gap': 29,
#                               'ids': ',usc000lv5e,',
#                               'mag': 5.1,
#                               'magType': 'mb',
#                               'mmi': None,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '76 km NNW of Davila, Philippines',
#                               'rms': 0.85,
#                               'sig': 400,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1388534476610,
#                               'title': 'M 5.1 - 76 km NNW of Davila, '
#                                        'Philippines',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',cap,origin,phase-data,',
#                               'tz': None,
#                               'updated': 1394151953000,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/usc000lv5e'},
#                'type': 'Feature'}],
#  'metadata': {'api': '1.14.0',
#               'count': 325,
#               'generated': 1705571823000,
#               'status': 200,
#               'title': 'USGS Earthquakes',
#               'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2014-01-01&endtime=2014-01-02'},
#  'type': 'FeatureCollection'}
